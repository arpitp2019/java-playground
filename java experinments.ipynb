// %%
ArrayList <Integer> list1 = new ArrayList<>();
ArrayList <Integer> list2 = new ArrayList<>();
ArrayList <ArrayList <Integer>> mainArray = new ArrayList<>();
mainArray.add(list1);
mainArray.add(list2);
// Out:
// true

// %%
mainArray.get(1).add(10);
// Out:
// true

// %%
mainArray
// Out:
// [[10, 20, 30], [30, 20, 10]]

// %%
if(mainArray.get(0).contains(50)){
    mainArray.get(1).add(40);
} else{
    mainArray.get(1).forEach(n -> System.out.println(n));
}
// Out:
// 30
// 20
// 10
// 40

// %%
// Out:
// [[10, 20, 30], [30, 20, 10, 40]]
