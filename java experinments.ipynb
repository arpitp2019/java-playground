// %%
String str = "hi this is arpit";

// %%
byte [] thiss = str.getBytes();

System.out.println(Arrays.toString(thiss));
// Out:
// [104, 105, 32, 116, 104, 105, 115, 32, 105, 115, 32, 97, 114, 112, 105, 116]

// %%
String converted = new String(thiss);
converted;
// Out:
// hi this is arpit

// %%
import java.io.FileInputStream;
import java.io.FileOutputStream;

// %%
FileInputStream readings = new FileInputStream("this is first file.txt");

// %%
// Out:
// 1284773866
