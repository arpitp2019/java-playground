// %%
import java.io.ByteArrayInputStream;
import java.io.ByteArrayOutputStream;
String s = "this is a string";
byte [] bytecollection = s.getBytes();

// %%
for (byte byto : bytecollection){
    System.out.println(byto);
}
// Out:
// 116
// 104
// 105
// 115
// 32
// 105
// 115
// 32
// 97
// 32
// 115
// 116
// 114
// 105
// 110
// 103

// %%
ByteArrayInputStream bis = new ByteArrayInputStream(bytecollection);
int data;
while ((data = bis.read())!= -1){
    System.out.println((char)data);
}
// Out:
// t
// h
// i
// s
//
// i
// s
//
// a
//
// s
// t
// r
// i
// n
// g

// %%
import java.io.FileOutputStream;
import java.io.IOException;

// CORRECT: output to a file
FileOutputStream fos1 = new FileOutputStream("newOutputStream1.txt"); 

// Example: Write byte 65 ('A') to the file
fos1.write(65); 

fos1.close(); // Always close file streams!
